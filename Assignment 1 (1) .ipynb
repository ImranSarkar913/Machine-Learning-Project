# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cardio_train.csv',sep=';')
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df['cardio'].value_counts()
# Out:
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64

# %%
sns.countplot(x = 'gender' , hue = 'cardio' , data = df)
plt.savefig("plots/Gender.png", dpi=300, bbox_inches='tight')

# %%
sns.countplot(x = 'cholesterol' , hue = 'cardio' , data = df)
plt.savefig("plots/Cholesterol.png", dpi=300, bbox_inches='tight')

# %%
sns.countplot(x = 'weight' , hue = 'cardio' , data = df)
# Out:
# <Axes: xlabel='weight', ylabel='count'>

# %%
sns.countplot(x = 'smoke' , hue = 'cardio' , data = df)
plt.savefig("plots/Smoke.png", dpi=300, bbox_inches='tight')

# %%
sns.countplot(x = 'alco' , hue = 'cardio' , data = df)
plt.savefig("plots/Alco.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# Class Distribution

# %%
df['cardio'].value_counts().plot(kind='bar')
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
df['cardio'].value_counts().plot(kind='bar', color=['skyblue', 'green'])
plt.title("Class Distribution of Cardio")
plt.xlabel("Cardio (0 = No Disease, 1 = Disease)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Age Distribution (Histogram)

# %%
plt.figure(figsize=(6,4))
(df['age'] / 365).plot(kind='hist', bins=30, color='green', edgecolor='black')
plt.title("Age Distribution of Patients")
plt.xlabel("Age (Years)")
plt.ylabel("Frequency")
plt.savefig("plots/age_distribution.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Height vs Weight (Scatter Plot)

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['height'], df['weight'], alpha=0.5)
plt.title("Height vs Weight")
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
plt.savefig("plots/height_vs_weight.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Cholesterol Levels (Bar Chart)

# %%
plt.figure(figsize=(6,4))
df['cholesterol'].value_counts().sort_index().plot(kind='bar', color='green')
plt.title("Cholesterol Level Distribution")
plt.xlabel("Cholesterol Level (1 = Normal, 2 = Above Normal, 3 = Well Above Normal)")
plt.ylabel("Count")
plt.savefig("plots/cholesterol_distribution.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.savefig("plots/correlation_heatmap.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Pair Plot (selected columns)

# %%
sns.pairplot(df[['age','height', 'weight', 'ap_hi', 'ap_lo', 'cardio']], hue='cardio', diag_kind='hist')
plt.suptitle("Pair Plot of Selected Features", y=1.02)
plt.savefig("plots/pair_plot.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Box Plot (Height by Cardio class)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x='cardio', y='height', data=df)
plt.title("Box Plot of Height by Cardio Class")
plt.xlabel("Cardio (0 = No Disease, 1 = Disease)")
plt.ylabel("Height (cm)")
plt.savefig("plots/boxplot_height_cardio.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Violin Plot (Weight by Cardio class)

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x='cardio', y='weight', data=df, palette='Set2')
plt.title("Violin Plot of Weight by Cardio Class")
plt.xlabel("Cardio (0 = No Disease, 1 = Disease)")
plt.ylabel("Weight (kg)")
plt.savefig("plots/violinplot_weight_cardio.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\IMRAN\AppData\Local\Temp\ipykernel_11864\229348641.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='cardio', y='weight', data=df, palette='Set2')

# %%
df = df.drop('id',axis=1)
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio
# ...

# %%
df['year'] = (df['age']/365).round(0)
df
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      18393       2     168    62.0    110     80            1     1      0
# 1      20228       1     156    85.0    140     90            3     1      0
# 2      18857       1     165    64.0    130     70            3     1      0
# 3      17623       2     169    82.0    150    100            1     1      0
# 4      17474       1     156    56.0    100     60            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 69995  19240       2     168    76.0    120     80            1     1      1
# 69996  22601       1     158   126.0    140     90            2     2      0
# 69997  19066       2     183   105.0    180     90            3     1      0
# 69998  22431       1     163    72.0    135     80            1     2      0
# 69999  20540       1     170    72.0    120     80            2     1      0
#
#        alco  active  cardio  year
# ...

# %%
df=df.drop('age',axis=1)
df
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  cardio  year
# ...

# %%
df.describe()
# Out:
#              gender        height        weight         ap_hi         ap_lo  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.349571    164.359229     74.205690    128.817286     96.630414
# std        0.476838      8.210126     14.395757    154.011419    188.472530
# min        1.000000     55.000000     10.000000   -150.000000    -70.000000
# 25%        1.000000    159.000000     65.000000    120.000000     80.000000
# 50%        1.000000    165.000000     72.000000    120.000000     80.000000
# 75%        2.000000    170.000000     82.000000    140.000000     90.000000
# max        2.000000    250.000000    200.000000  16020.000000  11000.000000
#
#         cholesterol          gluc         smoke          alco        active  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean       1.366871      1.226457      0.088129      0.053771      0.803729
# ...

# %%
df.corr()
# Out:
#                gender    height    weight     ap_hi     ap_lo  cholesterol  \
# gender       1.000000  0.499033  0.155406  0.006005  0.015254    -0.035821
# height       0.499033  1.000000  0.290968  0.005488  0.006150    -0.050226
# weight       0.155406  0.290968  1.000000  0.030702  0.043710     0.141768
# ap_hi        0.006005  0.005488  0.030702  1.000000  0.016086     0.023778
# ap_lo        0.015254  0.006150  0.043710  0.016086  1.000000     0.024019
# cholesterol -0.035821 -0.050226  0.141768  0.023778  0.024019     1.000000
# gluc        -0.020491 -0.018595  0.106857  0.011841  0.010806     0.451578
# smoke        0.338135  0.187989  0.067780 -0.000922  0.005186     0.010354
# alco         0.170966  0.094419  0.067113  0.001408  0.010601     0.035760
# active       0.005866 -0.006570 -0.016867 -0.000033  0.004780     0.009911
# cardio       0.008109 -0.010821  0.181660  0.054475  0.065719     0.221147
# ...

# %%
x = df.drop('cardio',axis=1)
x
# Out:
#        gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0           2     168    62.0    110     80            1     1      0     0
# 1           1     156    85.0    140     90            3     1      0     0
# 2           1     165    64.0    130     70            3     1      0     0
# 3           2     169    82.0    150    100            1     1      0     0
# 4           1     156    56.0    100     60            1     1      0     0
# ...       ...     ...     ...    ...    ...          ...   ...    ...   ...
# 69995       2     168    76.0    120     80            1     1      1     0
# 69996       1     158   126.0    140     90            2     2      0     0
# 69997       2     183   105.0    180     90            3     1      0     1
# 69998       1     163    72.0    135     80            1     2      0     0
# 69999       1     170    72.0    120     80            2     1      0     0
#
#        active  year
# 0           1  50.0
# ...

# %%
y = df['cardio']
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
x_scaled = StandardScaler().fit_transform(x)
x_scaled
# Out:
# array([[ 1.36405487,  0.44345206, -0.84787326, ..., -0.23838436,
#          0.49416711, -0.49350546],
#        [-0.73310834, -1.01816804,  0.74983117, ..., -0.23838436,
#          0.49416711,  0.24556599],
#        [-0.73310834,  0.07804703, -0.70894244, ..., -0.23838436,
#         -2.02360695, -0.19787688],
#        ...,
#        [ 1.36405487,  2.27047718,  2.13913938, ...,  4.19490608,
#         -2.02360695, -0.19787688],
#        [-0.73310834, -0.16555632, -0.15321916, ..., -0.23838436,
#         -2.02360695,  1.13245175],
#        [-0.73310834,  0.68705541, -0.15321916, ..., -0.23838436,
#          0.49416711,  0.39338029]])

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x_scaled , y , test_size = 0.30 , random_state = 1)

# %%
xtrain
# Out:
# array([[ 1.36405487,  0.56525373, -0.22268457, ..., -0.23838436,
#          0.49416711, -1.38039122],
#        [-0.73310834, -0.77456469, -0.36161539, ..., -0.23838436,
#          0.49416711, -1.97164838],
#        [-0.73310834, -0.04375464, -0.63947703, ..., -0.23838436,
#          0.49416711,  0.39338029],
#        ...,
#        [ 1.36405487,  1.66146881,  0.54143494, ..., -0.23838436,
#          0.49416711, -0.64131976],
#        [-0.73310834,  0.56525373,  0.19410789, ..., -0.23838436,
#         -2.02360695,  0.98463745],
#        [-0.73310834,  1.17426211, -0.63947703, ..., -0.23838436,
#          0.49416711,  0.54119458]])

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rclf = RandomForestClassifier()

# %%
rclf.fit(xtrain , ytrain)
# Out:
# RandomForestClassifier()

# %%
rclf.score(xtest , ytest)
# Out:
# 0.7043333333333334

# %% [markdown]
# Ensemble

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(RandomForestClassifier() , x , y , cv = 5)
scores
# Out:
# array([0.70407143, 0.70985714, 0.70628571, 0.70707143, 0.70192857])

# %%
scores.mean()
# Out:
# 0.7058428571428571

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag_model = BaggingClassifier(
    estimator = RandomForestClassifier(), 
    n_estimators = 100, 
    max_samples = 0.8, 
    oob_score = True,
    random_state = 0
)
bag_model.fit(xtrain, ytrain)
bag_model.oob_score_
# Out:
# 0.7218367346938775

# %%
bag_model.score(xtest , ytest)
# Out:
# 0.7211428571428572

# %%
from sklearn.metrics import roc_curve , auc ,accuracy_score , classification_report , confusion_matrix

# %%
pred = rclf.predict(xtest)
pred
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(ytest , pred)
# Out:
# 0.7043333333333334

# %%
cm = confusion_matrix(ytest, pred)
cm
# Out:
# array([[7436, 2916],
#        [3293, 7355]], dtype=int64)

# %%
(7456+7360)/(7360+7456+2896+3288)
# Out:
# 0.7055238095238096

# %%
cm = confusion_matrix(ytest, pred)

# %%
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.savefig("plots/CM Random forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
print(classification_report(ytest, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.71     10352
#            1       0.72      0.69      0.70     10648
#
#     accuracy                           0.70     21000
#    macro avg       0.70      0.70      0.70     21000
# weighted avg       0.70      0.70      0.70     21000

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
acc = accuracy_score(ytest, pred)
prec = precision_score(ytest, pred)
rec = recall_score(ytest, pred)
f1 = f1_score(ytest, pred)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.subplot(1,2,2)
plt.axis('off')
metrics_text = f"""
Accuracy  : {acc:.2f}
Precision : {prec:.2f}
Recall    : {rec:.2f}
F1-score  : {f1:.2f}
"""
plt.text(0.1, 0.5, metrics_text, fontsize=14, fontweight='bold', verticalalignment='center')

plt.suptitle("Model Evaluation Summary Random Forest", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig("plots/RF CR Random forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(ytest, pred)
roc_auc = auc(fpr, tpr)

# %% [markdown]
# ROC Curve

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='green', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig("plots/RF Roc.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(xtrain , ytrain)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(xtest , ytest)
# Out:
# 0.6309523809523809

# %% [markdown]
# Ensemble

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
score = cross_val_score(DecisionTreeClassifier(), x , y , cv=5)
score
# Out:
# array([0.63107143, 0.63685714, 0.64221429, 0.63407143, 0.63221429])

# %%
score.mean()
# Out:
# 0.6352857142857143

# %%
bag_model = BaggingClassifier(
    estimator = DecisionTreeClassifier(), 
    n_estimators = 100, 
    max_samples = 0.8, 
    oob_score = True,
    random_state = 0
)
bag_model.fit(xtrain, ytrain)
bag_model.oob_score_
# Out:
# 0.6987959183673469

# %%
bag_model = BaggingClassifier(
    estimator = DecisionTreeClassifier(), 
    n_estimators = 100, 
    max_samples = 0.8, 
    oob_score = True,
    random_state = 0
)
score = cross_val_score(bag_model, x, y, cv=5)
score

# %%
pred1 = dtc.predict(xtest)
pred1
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(ytest , pred1)
# Out:
# 0.6309523809523809

# %%
print(classification_report(ytest, pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64     10352
#            1       0.64      0.61      0.63     10648
#
#     accuracy                           0.63     21000
#    macro avg       0.63      0.63      0.63     21000
# weighted avg       0.63      0.63      0.63     21000

# %%
cm = confusion_matrix(ytest, pred1)
cm
# Out:
# array([[6753, 3599],
#        [4150, 6498]], dtype=int64)

# %%
(6796+6490)/(3556+6796+4158+6490)
# Out:
# 0.6326666666666667

# %%
acc = accuracy_score(ytest, pred1)
prec = precision_score(ytest, pred1)
rec = recall_score(ytest, pred1)
f1 = f1_score(ytest, pred1)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.subplot(1,2,2)
plt.axis('off')
metrics_text = f"""
Accuracy  : {acc:.2f}
Precision : {prec:.2f}
Recall    : {rec:.2f}
F1-score  : {f1:.2f}
"""
plt.text(0.1, 0.5, metrics_text, fontsize=14, fontweight='bold', verticalalignment='center')

plt.suptitle("Model Evaluation Summary Decision Tree", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig("plots/DT CR  forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(ytest, pred1)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='orange', lw=2, label=f'Decision Tree (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='blue', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Decision Tree')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig("plots/DT Roc .png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain , ytrain)
# Out:
# LogisticRegression()

# %%
lr.score(xtest , ytest)
# Out:
# 0.7184761904761905

# %% [markdown]
# Ensemble

# %%
score = cross_val_score(LogisticRegression(), x , y , cv=5)
score
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
score.mean()
# Out:
# 0.7066714285714286

# %%
bag_model = BaggingClassifier(
    estimator = LogisticRegression(), 
    n_estimators = 100, 
    max_samples = 0.8, 
    oob_score = True,
    random_state = 0
)
bag_model.fit(xtrain, ytrain)
bag_model.oob_score_
# Out:
# 0.7223061224489796

# %%
pred2 = lr.predict(xtest)
pred2
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(ytest , pred2)
# Out:
# 0.7184761904761905

# %%
cm = confusion_matrix(ytest, pred2)
cm
# Out:
# array([[7980, 2372],
#        [3540, 7108]], dtype=int64)

# %%
(7980 + 7108)/(7980+7108+3540+2372)
# Out:
# 0.7184761904761905

# %%
print(classification_report(ytest , pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.77      0.73     10352
#            1       0.75      0.67      0.71     10648
#
#     accuracy                           0.72     21000
#    macro avg       0.72      0.72      0.72     21000
# weighted avg       0.72      0.72      0.72     21000

# %%
acc = accuracy_score(ytest, pred2)
prec = precision_score(ytest, pred2)
rec = recall_score(ytest, pred2)
f1 = f1_score(ytest, pred2)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.subplot(1,2,2)
plt.axis('off')
metrics_text = f"""
Accuracy  : {acc:.2f}
Precision : {prec:.2f}
Recall    : {rec:.2f}
F1-score  : {f1:.2f}
"""
plt.text(0.1, 0.5, metrics_text, fontsize=14, fontweight='bold', verticalalignment='center')

plt.suptitle("Model Evaluation Summary Logistic Regression", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig("plots/LR CR forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(ytest, pred2)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='red', lw=2, label=f'Logistic Regression (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='black', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig("plots/LR Roc.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(xtrain , ytrain)
# Out:
# SVC()

# %%
svc.score(xtest , ytest)
# Out:
# 0.7235238095238096

# %% [markdown]
# Ensemble

# %%
score = cross_val_score(SVC(), x , y , cv=5)
score
# Out:
# array([0.721     , 0.72307143, 0.72278571, 0.71721429, 0.71742857])

# %%
score.mean()
# Out:
# 0.7203

# %%
pred3 = svc.predict(xtest)
pred3
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
cm = confusion_matrix(ytest, pred3)
cm
# Out:
# array([[7922, 2430],
#        [3376, 7272]], dtype=int64)

# %%
(7922+7272)/(7922+2430+3376+7272)
# Out:
# 0.7235238095238096

# %%
acc = accuracy_score(ytest, pred3)
prec = precision_score(ytest, pred3)
rec = recall_score(ytest, pred3)
f1 = f1_score(ytest, pred3)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.subplot(1,2,2)
plt.axis('off')
metrics_text = f"""
Accuracy  : {acc:.2f}
Precision : {prec:.2f}
Recall    : {rec:.2f}
F1-score  : {f1:.2f}
"""
plt.text(0.1, 0.5, metrics_text, fontsize=14, fontweight='bold', verticalalignment='center')

plt.suptitle("Model Evaluation Summary SVM", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig("plots/SVM CR Random forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
print(classification_report(ytest , pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73     10352
#            1       0.75      0.68      0.71     10648
#
#     accuracy                           0.72     21000
#    macro avg       0.73      0.72      0.72     21000
# weighted avg       0.73      0.72      0.72     21000

# %%
fpr, tpr, thresholds = roc_curve(ytest, pred3)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='green', lw=2, label=f'SVM (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - SVM')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
plt.savefig("plots/SVM Roc.png", dpi=300, bbox_inches='tight')

# %% [markdown]
# KNN ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier(n_neighbors=150)

# %%
kn.fit(xtrain , ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=150)

# %%
kn.score(xtest , ytest)
# Out:
# 0.6573333333333333

# %%
pred4 = kn.predict(xtest)
pred4
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cm = confusion_matrix(ytest , pred4)
cm
# Out:
# array([[7384, 2968],
#        [4228, 6420]], dtype=int64)

# %%
(7384+6420)/(7384+2968+4228+6420)
# Out:
# 0.6573333333333333

# %%
print(classification_report(ytest , pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67     10352
#            1       0.68      0.60      0.64     10648
#
#     accuracy                           0.66     21000
#    macro avg       0.66      0.66      0.66     21000
# weighted avg       0.66      0.66      0.66     21000

# %%
acc = accuracy_score(ytest, pred4)
prec = precision_score(ytest, pred4)
rec = recall_score(ytest, pred4)
f1 = f1_score(ytest, pred4)

# %%
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False,
            xticklabels=["No Disease", "Disease"],
            yticklabels=["No Disease", "Disease"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")

plt.subplot(1,2,2)
plt.axis('off')
metrics_text = f"""
Accuracy  : {acc:.2f}
Precision : {prec:.2f}
Recall    : {rec:.2f}
F1-score  : {f1:.2f}
"""
plt.text(0.1, 0.5, metrics_text, fontsize=14, fontweight='bold', verticalalignment='center')

plt.suptitle("Model Evaluation Summary KNN", fontsize=16, fontweight='bold')
plt.tight_layout()
plt.savefig("plots/KNN CR forst.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(ytest, pred4)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(6,6))
plt.plot(fpr, tpr, color='purple', lw=2, label=f'KNN (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='brown', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - KNN')
plt.legend(loc="lower right")
plt.grid(True)
plt.savefig("plots/KNN Roc.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Naive Vayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nv = GaussianNB()

# %%
nv.fit(xtrain , ytrain)
# Out:
# GaussianNB()

# %%
nv.score(xtest , ytest)
# Out:
# 0.5805714285714285

# %% [markdown]
# K-FOLD

# %%
from sklearn.model_selection import StratifiedKFold , KFold , cross_val_score
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
model = LogisticRegression()

# %%
kfc = KFold(n_splits = 5 , random_state = 1 , shuffle=True)
kfc_score = cross_val_score(model , x , y , cv = kfc)
kfc_score
# Out:
# array([0.71164286, 0.70114286, 0.70692857, 0.70392857, 0.70835714])

# %%
kfc_score.mean()
# Out:
# 0.7064

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)
skf_score = cross_val_score(model, x, y, cv=skf)
skf_score
# Out:
# array([0.70857143, 0.6975    , 0.70957143, 0.71121429, 0.70714286])

# %%
skf_score.mean()
# Out:
# 0.7068

# %% [markdown]
# FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest

# %%
from sklearn.feature_selection import f_classif

# %%
feature = SelectKBest(score_func = f_classif)

# %%
feature.fit(x , y)
# Out:
# SelectKBest()

# %%
score_col = pd.DataFrame(feature.scores_ , columns = ['score_value'])

# %%
name_col = pd.DataFrame(x.columns)

# %%
top_feature = pd.concat([name_col , score_col],axis=1)
top_feature
# Out:
#               0  score_value
# 0        gender     4.603641
# 1        height     8.197397
# 2        weight  2388.777887
# 3         ap_hi   208.339524
# 4         ap_lo   303.629011
# 5   cholesterol  3599.361137
# 6          gluc   562.772977
# 7         smoke    16.790541
# 8          alco     3.761355
# 9        active    89.091494
# 10         year  4193.661786

# %%
top_feature.nlargest(8,'score_value')
# Out:
#               0  score_value
# 10         year  4193.661786
# 5   cholesterol  3599.361137
# 2        weight  2388.777887
# 6          gluc   562.772977
# 4         ap_lo   303.629011
# 3         ap_hi   208.339524
# 9        active    89.091494
# 7         smoke    16.790541

# %%
x1 = x.drop('height',axis=1)

# %%
x2 = x1.drop('gender',axis=1)

# %%
x3 = x2.drop('alco',axis=1)

# %%
x3.shape
# Out:
# (70000, 8)

# %%
x3
# Out:
#        weight  ap_hi  ap_lo  cholesterol  gluc  smoke  active  year
# 0        62.0    110     80            1     1      0       1  50.0
# 1        85.0    140     90            3     1      0       1  55.0
# 2        64.0    130     70            3     1      0       0  52.0
# 3        82.0    150    100            1     1      0       1  48.0
# 4        56.0    100     60            1     1      0       0  48.0
# ...       ...    ...    ...          ...   ...    ...     ...   ...
# 69995    76.0    120     80            1     1      1       1  53.0
# 69996   126.0    140     90            2     2      0       1  62.0
# 69997   105.0    180     90            3     1      0       0  52.0
# 69998    72.0    135     80            1     2      0       0  61.0
# 69999    72.0    120     80            2     1      0       1  56.0
#
# [70000 rows x 8 columns]

# %%
y = df['cardio']
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
x3train , x3test , ytrain , ytest = train_test_split(x3 , y , test_size = 0.30 , random_state = 1)

# %%
x3train
# Out:
#        weight  ap_hi  ap_lo  cholesterol  gluc  smoke  active  year
# 23561    71.0    100     80            1     1      1       1  44.0
# 34858    69.0    140     80            2     1      0       1  40.0
# 54953    65.0    120     80            1     1      0       1  56.0
# 59230    53.0    100     60            1     1      0       1  46.0
# 1730     71.0    140     90            1     1      0       1  58.0
# ...       ...    ...    ...          ...   ...    ...     ...   ...
# 49100    78.0    120     80            1     1      0       1  58.0
# 20609    68.0    120     80            1     1      0       0  52.0
# 21440    82.0    120     80            1     1      0       1  49.0
# 50057    77.0    120     80            1     1      0       0  60.0
# 5192     65.0    160     90            2     2      0       1  57.0
#
# [49000 rows x 8 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rclf1 = RandomForestClassifier(n_estimators = 155)

# %%
rclf1.fit(x3train , ytrain)
# Out:
# RandomForestClassifier(n_estimators=155)

# %%
rclf1.score(x3test , ytest)
# Out:
# 0.6971904761904761

# %% [markdown]
# FEATURE IMPORTANCE

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
etc = ExtraTreesClassifier()

# %%
etc.fit(x , y)
# Out:
# ExtraTreesClassifier()

# %%
etc.feature_importances_
# Out:
# array([0.00626947, 0.22721418, 0.23525925, 0.20030886, 0.12053313,
#        0.04885309, 0.01191496, 0.00468137, 0.0047456 , 0.00494103,
#        0.13527905])

# %%
top = pd.Series(etc.feature_importances_, index = x.columns)
top
# Out:
# gender         0.006269
# height         0.227214
# weight         0.235259
# ap_hi          0.200309
# ap_lo          0.120533
# cholesterol    0.048853
# gluc           0.011915
# smoke          0.004681
# alco           0.004746
# active         0.004941
# year           0.135279
# dtype: float64

# %%
top.nlargest(10)
# Out:
# weight         0.235259
# height         0.227214
# ap_hi          0.200309
# year           0.135279
# ap_lo          0.120533
# cholesterol    0.048853
# gluc           0.011915
# gender         0.006269
# active         0.004941
# alco           0.004746
# dtype: float64

# %%
top.nlargest(10).plot(kind = 'bar')
# Out:
# <Axes: >

# %%
from sklearn.metrics import r2_score

# %%
preds = kn.predict(xtest)
preds
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
r2_score(ytest , preds)
# Out:
# -0.11222097132114106
